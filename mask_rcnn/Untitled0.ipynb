# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
import os
os.chdir("/content/gdrive/My Drive/Mask-rcnn/mask_rcnn/samples/urban_village")

# %%
ls
# Out:
# balloon/  coco/  demo.ipynb  nucleus/  shapes/  urban_village/

# %%
# !python identify_image_copy.py splash --weight=mask_rcnn_urban_village_0050.h5
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  142.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1039.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# Saved to  ../../../Xiamen_map_identify/map28-4.jpg
# Running on ../../../Xiamen_map/map28-7.jpg
# Processing 1 images
# image                    shape: (1039, 1003, 3)       min:    0.00000  max:  189.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   74.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1039.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# Saved to  ../../../Xiamen_map_identify/map28-7.jpg
# Running on ../../../Xiamen_map/map28-2.jpg
# Processing 1 images
# ...

# %%
pwd
# Out:
# '/content/gdrive/My Drive/Mask-rcnn'
